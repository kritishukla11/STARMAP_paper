# %% [markdown]
# # STARMAP network analysis figure panels
#
# This cleaned notebook is organized to generate the figure panels in order. It keeps only the imports, data loading, helper functions, derived tables, and plotting cells needed for the panels shown in the network analysis figure.
#
# Panel order:
# A. RTI-TRN network
# B. Regulatory breadth and amplitude
# C. TRN-TRN similarity matrix
# D. TRN module ontologies and biological roles
# E. RDI-drug network
# F. Drug breadth spectrum
# G. Drug-drug similarity matrix
# H. Module pharmacology
# I. TRN-drug association cross-talk
# J. Regulatory versus drug breadth
# K. Fraction of drug-linked proteins by TF breadth quintile
# L. Conceptual model

# %%
# Clean imports and global settings

from pathlib import Path
import warnings

import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

from scipy.stats import fisher_exact

warnings.filterwarnings("ignore", category=FutureWarning)

try:
    from community import community_louvain
    HAVE_LOUVAIN = True
except Exception:
    HAVE_LOUVAIN = False

plt.rcParams.update({
    "font.family": "Arial",
    "font.size": 8,
    "axes.titlesize": 8,
    "axes.labelsize": 8,
    "xtick.labelsize": 7,
    "ytick.labelsize": 7,
    "legend.fontsize": 7,
    "figure.dpi": 300,
    "savefig.dpi": 300,
})

OUTDIR = Path("figure_panels")
OUTDIR.mkdir(exist_ok=True)

# %%
# Data paths and analysis parameters

TRN_FILE = Path("top_protein_pathway_combos_clusterid.csv")
DRUG_FILE = Path("top_protein_drug_combos_clusterid.csv")

TRN_SCORE_THRESHOLD = 0.6
DRUG_SCORE_THRESHOLD = 1.0

MAX_PROTEIN_DEGREE = 300
MAX_TRN_DEGREE = 900
MAX_DRUG_DEGREE = 900

# %%
# Helper functions

def normalize_columns(df):
    """Standardize common column names without changing the original file on disk."""
    df = df.copy()
    if "Unnamed: 0" in df.columns and "protein" not in df.columns:
        df = df.rename(columns={"Unnamed: 0": "protein"})
    if df.index.name is not None and "protein" not in df.columns:
        df = df.reset_index().rename(columns={df.index.name: "protein"})
    return df


def read_trn_scores(path=TRN_FILE):
    """Read protein-TRN Gi* scores."""
    df = pd.read_csv(path, index_col=0)
    df = df.reset_index().rename(columns={"index": "protein"})
    df = df.rename(columns={"pathway": "trn"})
    required = {"protein", "trn", "score"}
    missing = required - set(df.columns)
    if missing:
        raise ValueError(f"TRN file is missing required columns: {missing}")
    df["score"] = pd.to_numeric(df["score"], errors="coerce")
    return df.dropna(subset=["protein", "trn", "score"])


def read_drug_scores(path=DRUG_FILE):
    """Read protein-drug association scores."""
    df = pd.read_csv(path)
    df = normalize_columns(df)
    required = {"protein", "drug", "score"}
    missing = required - set(df.columns)
    if missing:
        raise ValueError(f"Drug file is missing required columns: {missing}")
    df["score"] = pd.to_numeric(df["score"], errors="coerce")
    return df.dropna(subset=["protein", "drug", "score"])


def build_bipartite_graph(
    df,
    left_col,
    right_col,
    score_col="score",
    left_type="protein",
    right_type="feature",
    score_threshold=None,
    use_abs_for_threshold=True,
):
    """Build a weighted bipartite graph from a long-form score table."""
    d = df[[left_col, right_col, score_col]].dropna().copy()
    d[left_col] = d[left_col].astype(str)
    d[right_col] = d[right_col].astype(str)
    d[score_col] = pd.to_numeric(d[score_col], errors="coerce")
    d = d.dropna(subset=[score_col])
    d = d[d[left_col] != d[right_col]]

    if score_threshold is not None:
        if use_abs_for_threshold:
            d = d[d[score_col].abs() >= score_threshold]
        else:
            d = d[d[score_col] >= score_threshold]

    G = nx.Graph()
    for n in d[left_col].unique():
        G.add_node(n, node_type=left_type, bipartite=0)
    for n in d[right_col].unique():
        G.add_node(n, node_type=right_type, bipartite=1)

    for row in d.itertuples(index=False):
        left = getattr(row, left_col)
        right = getattr(row, right_col)
        score = float(getattr(row, score_col))
        G.add_edge(left, right, score=score, weight=abs(score), weight_abs=abs(score))

    return G, d


def filter_bipartite_by_degree(
    G,
    max_left_degree=300,
    max_right_degree=900,
    left_type="protein",
    right_type="feature",
    drop_isolates=True,
):
    """Remove extreme high-degree background nodes and optionally drop isolates."""
    keep = []
    for n, a in G.nodes(data=True):
        node_type = a.get("node_type")
        deg = G.degree(n)
        if node_type == left_type and deg <= max_left_degree:
            keep.append(n)
        elif node_type == right_type and deg <= max_right_degree:
            keep.append(n)

    Gf = G.subgraph(keep).copy()
    if drop_isolates:
        Gf.remove_nodes_from(list(nx.isolates(Gf)))
    return Gf


def summarize_protein_nodes(G, feature_type):
    """Return degree and amplitude summaries for protein nodes in a bipartite graph."""
    rows = []
    for p, a in G.nodes(data=True):
        if a.get("node_type") != "protein":
            continue

        edges = list(G.edges(p, data=True))
        if not edges:
            continue

        vals = np.array([abs(d["score"]) for _, _, d in edges], dtype=float)
        rows.append({
            "protein": p,
            f"{feature_type}_degree": G.degree(p),
            f"mean_abs_{feature_type}": float(vals.mean()),
            f"p95_abs_{feature_type}": float(np.percentile(vals, 95)),
            f"max_abs_{feature_type}": float(vals.max()),
        })

    return pd.DataFrame(rows)


def feature_jaccard_matrix(G, feature_type):
    """Compute feature-feature Jaccard similarity based on shared protein neighbors."""
    features = [n for n, a in G.nodes(data=True) if a.get("node_type") == feature_type]
    feature_to_proteins = {
        f: {nbr for nbr in G.neighbors(f) if G.nodes[nbr].get("node_type") == "protein"}
        for f in features
    }

    J = np.zeros((len(features), len(features)), dtype=float)
    for i, fi in enumerate(features):
        A = feature_to_proteins[fi]
        for j in range(i, len(features)):
            B = feature_to_proteins[features[j]]
            union = len(A | B)
            sim = len(A & B) / union if union else 0.0
            J[i, j] = sim
            J[j, i] = sim

    return features, J, feature_to_proteins


def similarity_graph(features, J, percentile=95):
    """Threshold a Jaccard matrix and return a feature similarity graph."""
    off = J[np.triu_indices_from(J, k=1)]
    off_nonzero = off[off > 0]
    threshold = float(np.percentile(off_nonzero, percentile)) if len(off_nonzero) else 0.0

    H = nx.Graph()
    H.add_nodes_from(features)
    for i in range(len(features)):
        for j in range(i + 1, len(features)):
            if J[i, j] >= threshold:
                H.add_edge(features[i], features[j], weight=float(J[i, j]))

    return H, threshold


def detect_modules(H):
    """Detect modules with Louvain when available, otherwise use connected components."""
    if HAVE_LOUVAIN and H.number_of_edges() > 0:
        part = community_louvain.best_partition(H, weight="weight", random_state=1)
    else:
        part = {}
        for i, comp in enumerate(nx.connected_components(H)):
            for n in comp:
                part[n] = i

    return pd.DataFrame({"feature": list(part.keys()), "module": list(part.values())})


def ordered_matrix(features, J, module_df, feature_col="feature"):
    """Order a similarity matrix by module labels."""
    mod_map = dict(zip(module_df[feature_col], module_df["module"]))
    order = sorted(range(len(features)), key=lambda i: (mod_map.get(features[i], 999), features[i]))
    return J[np.ix_(order, order)], [features[i] for i in order], [mod_map.get(features[i], -1) for i in order]


def classify_proteins(prot_df, degree_col="trn_degree"):
    """Add specific, intermediate, and pleiotropic labels by degree."""
    out = prot_df.copy()
    q25 = out[degree_col].quantile(0.25)
    q90 = out[degree_col].quantile(0.90)

    out["class"] = "intermediate"
    out.loc[out[degree_col] <= q25, "class"] = "specific"
    out.loc[out[degree_col] >= q90, "class"] = "pleiotropic"
    return out, q25, q90


def save_panel(fig, name):
    """Save a panel as SVG and PDF."""
    fig.savefig(OUTDIR / f"{name}.svg", bbox_inches="tight")
    fig.savefig(OUTDIR / f"{name}.pdf", bbox_inches="tight")

# %%
# Read data

trn_scores = read_trn_scores(TRN_FILE)
drug_scores = read_drug_scores(DRUG_FILE)

display(trn_scores.head())
display(drug_scores.head())

# %%
# Build TRN and drug networks

G_trn_raw, trn_edges = build_bipartite_graph(
    trn_scores,
    left_col="protein",
    right_col="trn",
    left_type="protein",
    right_type="trn",
    score_threshold=TRN_SCORE_THRESHOLD,
    use_abs_for_threshold=True,
)

G_trn = filter_bipartite_by_degree(
    G_trn_raw,
    max_left_degree=MAX_PROTEIN_DEGREE,
    max_right_degree=MAX_TRN_DEGREE,
    left_type="protein",
    right_type="trn",
)

G_drug_raw, drug_edges = build_bipartite_graph(
    drug_scores,
    left_col="protein",
    right_col="drug",
    left_type="protein",
    right_type="drug",
    score_threshold=DRUG_SCORE_THRESHOLD,
    use_abs_for_threshold=True,
)

G_drug = filter_bipartite_by_degree(
    G_drug_raw,
    max_left_degree=MAX_PROTEIN_DEGREE,
    max_right_degree=MAX_DRUG_DEGREE,
    left_type="protein",
    right_type="drug",
)

print(f"TRN network: {G_trn.number_of_nodes():,} nodes, {G_trn.number_of_edges():,} edges")
print(f"Drug network: {G_drug.number_of_nodes():,} nodes, {G_drug.number_of_edges():,} edges")

# %%
# Derived tables used by multiple panels

trn_prot = summarize_protein_nodes(G_trn, "trn")
drug_prot = summarize_protein_nodes(G_drug, "drug")

prot_df = trn_prot.merge(
    drug_prot[["protein", "drug_degree", "p95_abs_drug", "max_abs_drug"]],
    on="protein",
    how="left",
)

prot_df["drug_degree"] = prot_df["drug_degree"].fillna(0).astype(int)
prot_df["p95_abs_drug"] = prot_df["p95_abs_drug"].fillna(0)
prot_df["max_abs_drug"] = prot_df["max_abs_drug"].fillna(0)
prot_df["drug_linked"] = prot_df["drug_degree"] > 0

prot_df, trn_p25, trn_p90 = classify_proteins(prot_df, degree_col="trn_degree")

trn_features, J_trn, trn_to_proteins = feature_jaccard_matrix(G_trn, "trn")
H_trn, trn_jaccard_threshold = similarity_graph(trn_features, J_trn, percentile=95)
trn_modules = detect_modules(H_trn).rename(columns={"feature": "trn"})
J_trn_ord, trns_ord, trn_mods_ord = ordered_matrix(trn_features, J_trn, trn_modules, feature_col="trn")

drug_features, J_drug, drug_to_proteins = feature_jaccard_matrix(G_drug, "drug")
H_drug, drug_jaccard_threshold = similarity_graph(drug_features, J_drug, percentile=95)
drug_modules = detect_modules(H_drug).rename(columns={"feature": "drug"})
J_drug_ord, drugs_ord, drug_mods_ord = ordered_matrix(drug_features, J_drug, drug_modules, feature_col="drug")

print(f"TRN Jaccard threshold: {trn_jaccard_threshold:.3f}")
print(f"Drug Jaccard threshold: {drug_jaccard_threshold:.3f}")
display(prot_df.head())

# %% [markdown]
# ## Panel A. RTI-TRN network

# %%
# Panel A: example RTI-TRN bipartite network

example_proteins = ["KRAS", "KEAP1", "BRAF", "CDX1", "ARID5B", "NRF2"]
available = [p for p in example_proteins if p in G_trn]

if len(available) < 2:
    available = (
        prot_df.sort_values("trn_degree", ascending=False)
        .head(6)["protein"]
        .tolist()
    )

nodes = set(available)
for p in available:
    trn_neighbors = [
        n for n in G_trn.neighbors(p)
        if G_trn.nodes[n].get("node_type") == "trn"
    ][:10]
    nodes.update(trn_neighbors)

G_panel = G_trn.subgraph(nodes).copy()
pos = nx.spring_layout(G_panel, seed=2, k=0.7)

fig, ax = plt.subplots(figsize=(3.2, 2.4))

protein_nodes = [n for n, a in G_panel.nodes(data=True) if a.get("node_type") == "protein"]
trn_nodes = [n for n, a in G_panel.nodes(data=True) if a.get("node_type") == "trn"]

nx.draw_networkx_edges(G_panel, pos, ax=ax, width=0.4, alpha=0.35)
nx.draw_networkx_nodes(G_panel, pos, nodelist=trn_nodes, node_size=45, ax=ax)
nx.draw_networkx_nodes(G_panel, pos, nodelist=protein_nodes, node_size=180, ax=ax)

labels = {n: n for n in protein_nodes}
nx.draw_networkx_labels(G_panel, pos, labels=labels, font_size=6, ax=ax)

ax.set_title("RTI-TRN network", pad=4)
ax.axis("off")
plt.tight_layout(pad=0.2)
save_panel(fig, "panel_a_rti_trn_network")
plt.show()

# %% [markdown]
# ## Panel B. Spectrum of regulatory breadth and amplitude

# %%
# Panel B: regulatory breadth histogram and breadth-amplitude scatter

fig, (ax_hist, ax_scatter) = plt.subplots(
    2, 1,
    figsize=(3.2, 4.0),
    gridspec_kw={"height_ratios": [1, 1.4]},
)

deg_vals = prot_df["trn_degree"]

ax_hist.hist(deg_vals, bins=35)
ax_hist.axvline(trn_p25, linestyle="--", linewidth=0.8, label="P25")
ax_hist.axvline(trn_p90, linestyle=":", linewidth=0.8, label="P90")
ax_hist.set_ylabel("Count")
ax_hist.set_title("Spectrum of regulatory breadth and amplitude", pad=4)
ax_hist.legend(frameon=False)

ax_scatter.scatter(
    prot_df["trn_degree"],
    prot_df["p95_abs_trn"],
    s=7,
    alpha=0.55,
    linewidths=0,
)
ax_scatter.axvline(trn_p25, linestyle="--", linewidth=0.8)
ax_scatter.axvline(trn_p90, linestyle=":", linewidth=0.8)
ax_scatter.set_xlabel("Protein degree (TF breadth)")
ax_scatter.set_ylabel("P95 |Gi*|")

top_labels = prot_df.sort_values(["p95_abs_trn", "trn_degree"], ascending=False).head(8)
for _, row in top_labels.iterrows():
    ax_scatter.text(row["trn_degree"] + 2, row["p95_abs_trn"], row["protein"], fontsize=5)

plt.tight_layout(pad=0.5)
save_panel(fig, "panel_b_regulatory_breadth_amplitude")
plt.show()

# %% [markdown]
# ## Panel C. TRN-TRN similarity matrix

# %%
# Panel C: TRN-TRN Jaccard similarity matrix and module enrichment summary

fig, (ax_heat, ax_bar) = plt.subplots(
    2, 1,
    figsize=(3.0, 3.8),
    gridspec_kw={"height_ratios": [2.2, 1]},
)

im = ax_heat.imshow(J_trn_ord, aspect="auto", interpolation="nearest")
ax_heat.set_xticks([])
ax_heat.set_yticks([])
ax_heat.set_title("TRN-TRN similarity matrix", pad=4)
cbar = fig.colorbar(im, ax=ax_heat, fraction=0.05, pad=0.03)
cbar.set_label("Jaccard", fontsize=8)

# Enrichment of TRN modules in pleiotropic versus specific protein classes
trn_mod_map = dict(zip(trn_modules["trn"], trn_modules["module"]))
prot_to_trns = {
    p: {n for n in G_trn.neighbors(p) if G_trn.nodes[n].get("node_type") == "trn"}
    for p in prot_df["protein"]
    if p in G_trn
}

def trns_for_class(class_name):
    proteins = prot_df.loc[prot_df["class"] == class_name, "protein"]
    out = set()
    for p in proteins:
        out.update(prot_to_trns.get(p, set()))
    return out

pleio_trns = trns_for_class("pleiotropic")
specific_trns = trns_for_class("specific")

rows = []
for m in sorted(set(trn_mod_map.values())):
    module_trns = {t for t, mod in trn_mod_map.items() if mod == m}
    a = len(module_trns & pleio_trns)
    c = len(module_trns & specific_trns)
    b = max(len(pleio_trns) - a, 0)
    d = max(len(specific_trns) - c, 0)
    odds, pval = fisher_exact([[a, b], [c, d]], alternative="greater")
    rows.append({"module": m, "log2_or": np.log2(odds) if np.isfinite(odds) and odds > 0 else np.nan, "p_value": pval})

module_enrich = pd.DataFrame(rows).sort_values("p_value")
plot_enrich = module_enrich.head(10).copy()
plot_enrich["label"] = [chr(97 + i) for i in range(len(plot_enrich))]

ax_bar.bar(plot_enrich["label"], plot_enrich["log2_or"].fillna(0))
ax_bar.set_xlabel("TRN module")
ax_bar.set_ylabel("log2 OR")

plt.tight_layout(pad=0.5)
save_panel(fig, "panel_c_trn_similarity")
plt.show()

display(module_enrich.head(10))

# %% [markdown]
# ## Panel D. Module ontologies and biological roles

# %%
# Panel D: curated module role heatmap
# Edit this table if final curated annotations change.

role_frac_clean = pd.DataFrame({
    "b": [0.30, 0.40, 0.10, 0.15, 0.10, 0.02, 0.22, 0.00],
    "c": [0.42, 0.24, 0.16, 0.18, 0.02, 0.08, 0.12, 0.04],
    "a": [0.36, 0.26, 0.18, 0.14, 0.08, 0.06, 0.10, 0.00],
}, index=[
    "Zinc finger TFs",
    "Developmental TFs",
    "Chromatin/epigenetic",
    "Transcription cofactors",
    "Genome maintenance",
    "RNA processing",
    "Signaling",
    "Metabolic",
])

fig, ax = plt.subplots(figsize=(2.2, 2.7))
im = ax.imshow(role_frac_clean.values, aspect="auto", interpolation="nearest")

ax.set_xticks(range(role_frac_clean.shape[1]))
ax.set_xticklabels(role_frac_clean.columns)
ax.set_yticks(range(role_frac_clean.shape[0]))
ax.set_yticklabels(role_frac_clean.index)
ax.set_title("Module ontologies and biological roles", pad=4)
ax.tick_params(length=0)

for spine in ax.spines.values():
    spine.set_visible(False)

cbar = fig.colorbar(im, ax=ax, fraction=0.05, pad=0.03)
cbar.set_label("Fraction of module", fontsize=8)

plt.tight_layout(pad=0.4)
save_panel(fig, "panel_d_module_ontologies")
plt.show()

# %% [markdown]
# ## Panel E. RDI-drug network

# %%
# Panel E: example RDI-drug bipartite network

example_proteins = ["KRAS", "BRAF", "TP53"]
available = [p for p in example_proteins if p in G_drug]

if len(available) < 2:
    available = (
        drug_prot.sort_values("drug_degree", ascending=False)
        .head(4)["protein"]
        .tolist()
    )

nodes = set(available)
for p in available:
    drug_neighbors = [
        n for n in G_drug.neighbors(p)
        if G_drug.nodes[n].get("node_type") == "drug"
    ][:12]
    nodes.update(drug_neighbors)

G_panel = G_drug.subgraph(nodes).copy()
pos = nx.spring_layout(G_panel, seed=5, k=0.8)

fig, ax = plt.subplots(figsize=(3.2, 2.4))

protein_nodes = [n for n, a in G_panel.nodes(data=True) if a.get("node_type") == "protein"]
drug_nodes = [n for n, a in G_panel.nodes(data=True) if a.get("node_type") == "drug"]

nx.draw_networkx_edges(G_panel, pos, ax=ax, width=0.4, alpha=0.35)
nx.draw_networkx_nodes(G_panel, pos, nodelist=drug_nodes, node_size=45, ax=ax)
nx.draw_networkx_nodes(G_panel, pos, nodelist=protein_nodes, node_size=180, ax=ax)

labels = {n: n for n in protein_nodes}
nx.draw_networkx_labels(G_panel, pos, labels=labels, font_size=6, ax=ax)

ax.set_title("RDI-drug network", pad=4)
ax.axis("off")
plt.tight_layout(pad=0.2)
save_panel(fig, "panel_e_rdi_drug_network")
plt.show()

# %% [markdown]
# ## Panel F. Spectrum of drug breadth

# %%
# Panel F: drug breadth histogram

drug_p25 = drug_prot["drug_degree"].quantile(0.25)
drug_p90 = drug_prot["drug_degree"].quantile(0.90)

fig, ax = plt.subplots(figsize=(3.0, 2.2))
ax.hist(drug_prot["drug_degree"], bins=30)
ax.axvline(drug_p25, linestyle="--", linewidth=0.8, label="P25")
ax.axvline(drug_p90, linestyle=":", linewidth=0.8, label="P90")
ax.set_xlabel("Protein degree (Drug breadth)")
ax.set_ylabel("Count")
ax.set_title("Spectrum of drug breadth", pad=4)
ax.legend(frameon=False)

plt.tight_layout(pad=0.4)
save_panel(fig, "panel_f_drug_breadth")
plt.show()

# %% [markdown]
# ## Panel G. Drug-drug similarity matrix

# %%
# Panel G: drug-drug Jaccard similarity matrix and module enrichment summary

fig, (ax_heat, ax_bar) = plt.subplots(
    2, 1,
    figsize=(3.0, 3.8),
    gridspec_kw={"height_ratios": [2.2, 1]},
)

im = ax_heat.imshow(J_drug_ord, aspect="auto", interpolation="nearest")
ax_heat.set_xticks([])
ax_heat.set_yticks([])
ax_heat.set_title("Drug-drug similarity matrix", pad=4)
cbar = fig.colorbar(im, ax=ax_heat, fraction=0.05, pad=0.03)
cbar.set_label("Jaccard", fontsize=8)

drug_mod_map = dict(zip(drug_modules["drug"], drug_modules["module"]))
drug_module_sizes = drug_modules["module"].value_counts().sort_values(ascending=False)
plot_drug_modules = drug_module_sizes.head(5)

ax_bar.bar([chr(97 + i) for i in range(len(plot_drug_modules))], plot_drug_modules.values)
ax_bar.set_xlabel("Drug module")
ax_bar.set_ylabel("Module size")

plt.tight_layout(pad=0.5)
save_panel(fig, "panel_g_drug_similarity")
plt.show()

display(drug_modules.groupby("module")["drug"].apply(list).sort_index().head())

# %% [markdown]
# ## Panel H. Module pharmacology

# %%
# Panel H: curated pharmacology categories for the largest drug module
# Edit this table after final manual module annotation.

module_pharm = pd.Series({
    "Kinase signaling": 0.30,
    "Cell cycle": 0.15,
    "Proteostasis/degradation": 0.12,
    "DNA damage & repair": 0.10,
    "Chaperone / stress": 0.08,
    "Receptor / GPCR signaling": 0.07,
    "Unknown / screening cmpds": 0.18,
})

fig, ax = plt.subplots(figsize=(2.2, 2.7))
im = ax.imshow(module_pharm.to_frame("a").values, aspect="auto", interpolation="nearest")

ax.set_xticks([0])
ax.set_xticklabels(["a"])
ax.set_yticks(range(len(module_pharm)))
ax.set_yticklabels(module_pharm.index)
ax.set_title("Module pharmacology", pad=4)
ax.tick_params(length=0)

for spine in ax.spines.values():
    spine.set_visible(False)

cbar = fig.colorbar(im, ax=ax, fraction=0.08, pad=0.04)
cbar.set_label("Fraction of module", fontsize=8)

plt.tight_layout(pad=0.4)
save_panel(fig, "panel_h_module_pharmacology")
plt.show()

# %% [markdown]
# ## Panel I. TRN-drug association cross-talk

# %%
# Panel I: cross-talk between TRN modules and drug modules through shared proteins

prot_to_trn_modules = {}
for p in prot_df["protein"]:
    trns = prot_to_trns.get(p, set())
    prot_to_trn_modules[p] = {trn_mod_map[t] for t in trns if t in trn_mod_map}

prot_to_drug_modules = {}
for p in prot_df["protein"]:
    if p not in G_drug:
        prot_to_drug_modules[p] = set()
        continue
    drugs = {n for n in G_drug.neighbors(p) if G_drug.nodes[n].get("node_type") == "drug"}
    prot_to_drug_modules[p] = {drug_mod_map[d] for d in drugs if d in drug_mod_map}

rows = []
for p in prot_df["protein"]:
    for tm in prot_to_trn_modules.get(p, set()):
        for dm in prot_to_drug_modules.get(p, set()):
            rows.append({"protein": p, "trn_module": tm, "drug_module": dm})

cross_links = pd.DataFrame(rows)
if cross_links.empty:
    cross_df = pd.DataFrame(columns=["trn_module", "drug_module", "overlap_proteins"])
else:
    cross_df = (
        cross_links
        .groupby(["trn_module", "drug_module"])["protein"]
        .nunique()
        .reset_index(name="overlap_proteins")
        .sort_values("overlap_proteins", ascending=False)
    )

# Draw a simple alluvial-like cross-talk panel
fig, ax = plt.subplots(figsize=(3.2, 2.2))

top_cross = cross_df.head(80).copy()
if not top_cross.empty:
    trn_order = {m: i for i, m in enumerate(sorted(top_cross["trn_module"].unique()))}
    drug_order = {m: i for i, m in enumerate(sorted(top_cross["drug_module"].unique()))}

    for _, row in top_cross.iterrows():
        y0 = trn_order[row["trn_module"]]
        y1 = drug_order[row["drug_module"]]
        lw = 0.2 + 1.5 * row["overlap_proteins"] / top_cross["overlap_proteins"].max()
        ax.plot([0, 1], [y0, y1], linewidth=lw, alpha=0.15)

    ax.scatter(np.zeros(len(trn_order)), list(trn_order.values()), s=5)
    ax.scatter(np.ones(len(drug_order)), list(drug_order.values()), s=5)

ax.set_xlim(-0.05, 1.05)
ax.set_xticks([0, 1])
ax.set_xticklabels(["TRN modules", "Drug modules"])
ax.set_yticks([])
ax.set_title("TRN-drug association cross-talk", pad=4)
for spine in ax.spines.values():
    spine.set_visible(False)

plt.tight_layout(pad=0.4)
save_panel(fig, "panel_i_trn_drug_crosstalk")
plt.show()

display(cross_df.head(10))

# %% [markdown]
# ## Panel J. Regulatory versus drug breadth

# %%
# Panel J: regulatory breadth versus drug breadth

fig, ax = plt.subplots(figsize=(3.0, 2.3))

ax.scatter(
    prot_df["trn_degree"],
    prot_df["drug_degree"],
    s=8,
    alpha=0.55,
    linewidths=0,
)

ax.axvspan(0, trn_p25, alpha=0.10, label="Specific proteins")
ax.axvspan(trn_p25, trn_p90, alpha=0.10, label="Intermediate")
ax.axvspan(trn_p90, prot_df["trn_degree"].max(), alpha=0.10, label="Pleiotropic proteins")

ax.set_xlabel("TF breadth")
ax.set_ylabel("Drug breadth")
ax.set_title("Regulatory vs drug breadth", pad=4)
ax.legend(frameon=False, loc="upper left")

plt.tight_layout(pad=0.4)
save_panel(fig, "panel_j_regulatory_vs_drug_breadth")
plt.show()

# %% [markdown]
# ## Panel K. Fraction of drug-linked proteins by TF breadth quintile

# %%
# Panel K: drug-linked fraction across TF breadth quintiles

plot_df = prot_df[["protein", "trn_degree", "drug_degree"]].copy()
plot_df["drug_linked"] = plot_df["drug_degree"] > 0
plot_df["tf_breadth_quintile"] = pd.qcut(plot_df["trn_degree"], q=5, labels=["Q1", "Q2", "Q3", "Q4", "Q5"], duplicates="drop")

bin_summary = (
    plot_df.groupby("tf_breadth_quintile", observed=True)
    .agg(
        n_proteins=("protein", "count"),
        frac_drug_linked=("drug_linked", "mean"),
        median_tf_breadth=("trn_degree", "median"),
    )
    .reset_index()
)

fig, ax = plt.subplots(figsize=(3.0, 2.3))

x = np.arange(len(bin_summary))
y = bin_summary["frac_drug_linked"].values

ax.plot(x, y, marker="o", linewidth=1)

for i, row in bin_summary.iterrows():
    ax.text(i, y[i] + 0.002, f"N={int(row['n_proteins'])}", ha="center", fontsize=6)

ax.set_xticks(x)
ax.set_xticklabels(bin_summary["tf_breadth_quintile"])
ax.set_xlabel("TF breadth quintile")
ax.set_ylabel("Fraction of drug-linked")
ax.set_title("Regulatory vs drug breadth", pad=4)

plt.tight_layout(pad=0.4)
save_panel(fig, "panel_k_drug_linked_by_quintile")
plt.show()

display(bin_summary)

# %% [markdown]
# ## Panel L. Conceptual model

# %%
# Panel L: conceptual model for breadth and therapeutic vulnerability

x = np.linspace(0, 1, 400)
y = np.exp(-((x - 0.5) ** 2) / (2 * 0.14 ** 2))
y = y / y.max()

fig, ax = plt.subplots(figsize=(3.2, 2.0))

ax.plot(x, y, linewidth=1.5)
ax.fill_between(x, 0, y, alpha=0.15)

ax.axvline(0.25, linestyle="--", linewidth=0.8)
ax.axvline(0.75, linestyle="--", linewidth=0.8)

ax.text(0.12, 1.05, "Specific", ha="center", fontsize=7)
ax.text(0.50, 1.05, "Intermediate", ha="center", fontsize=7)
ax.text(0.88, 1.05, "Pleiotropic", ha="center", fontsize=7)

ax.set_xlabel("Regulatory breadth (TRN connectivity)")
ax.set_ylabel("Drug sensitivity")
ax.set_title("Intermediate regulatory engagement maximizes vulnerability", pad=4)

ax.set_xticks([])
ax.set_yticks([])
for spine in ax.spines.values():
    spine.set_visible(False)

plt.tight_layout(pad=0.4)
save_panel(fig, "panel_l_conceptual_model")
plt.show()

# %% [markdown]
# ## Output files
#
# Each plotting cell saves both SVG and PDF versions into the `figure_panels/` folder.
