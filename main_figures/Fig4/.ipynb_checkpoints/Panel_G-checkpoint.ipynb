# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize, LinearSegmentedColormap

# %%
df = pd.read_csv('data/top_protein_drugs_score_matrix.csv',index_col=0)

# %%
sorted_values = np.sort(df.to_numpy(dtype=float), axis=1)[:, ::-1]

# Make back into DataFrame
df_row_sorted = pd.DataFrame(
    sorted_values,
    index=df.index,
    columns=[f"rank_{i+1}" for i in range(df.shape[1])]
)

protein_order = np.argsort(df_row_sorted.iloc[:, 0].to_numpy())[::-1]
df_final = df_row_sorted.iloc[protein_order]

zero_counts = (df_final == 0).sum(axis=1)

df_final = df_final[zero_counts <= 100]
df_subset = df_final.loc[:, (df_final == 0).mean(axis=0) <= 0.75]

# %%
plt.figure(figsize=(12, 6))

data = df_final.to_numpy()
vmin = np.nanmin(data)
vmax = np.nanmax(data)
vcenter =  2.197

# position of white within the full data range
p = (vcenter - vmin) / (vmax - vmin)

# keep p in [0,1] just in case
p = np.clip(p, 0, 1)

# custom blue-white-red colormap with white at vcenter
cmap = LinearSegmentedColormap.from_list(
    "custom_bwr",
    [
        (0.0, "blue"),
        (p, "white"),
        (1.0, "red"),
    ]
)

norm = Normalize(vmin=vmin, vmax=vmax)

im = plt.imshow(
    df_subset.T,
    aspect='auto',
    cmap=cmap,
    norm=norm,
    interpolation='nearest'
)

cbar = plt.colorbar(im, label='Log Odds Score',pad=0.01)
cbar.set_label(label='Log Odds Score', fontsize=20)
cbar.ax.tick_params(labelsize=16)

plt.xlabel('Proteins',fontsize=20)
plt.ylabel('Sorted drug rank within protein',fontsize=20)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig("drug_heatmap.svg")
plt.show()

# %%
top10 = df_final.head(int(len(df_final) * 0.10))
top10sub = df_subset.head(int(len(df_subset) * 0.10))

# %%
plt.figure(figsize=(12, 6))

data = df_final.to_numpy()
vmin = np.nanmin(data)
vmax = np.nanmax(data)
vcenter =  5

# position of white within the full data range
p = (vcenter - vmin) / (vmax - vmin)

# keep p in [0,1] just in case
p = np.clip(p, 0, 1)

# custom blue-white-red colormap with white at vcenter
cmap = LinearSegmentedColormap.from_list(
    "custom_bwr",
    [
        (0.0, "blue"),
        (p, "white"),
        (1.0, "red"),
    ]
)

norm = Normalize(vmin=vmin, vmax=vmax)

im = plt.imshow(
    top10.T,
    aspect='auto',
    cmap=cmap,
    norm=norm,
    interpolation='nearest'
)

cbar = plt.colorbar(im, label='Log Odds Score',pad=0.01)
cbar.set_label(label='Log Odds Score', fontsize=20)
cbar.ax.tick_params(labelsize=16)

plt.xlabel('Proteins',fontsize=20)
plt.ylabel('Sorted drug rank within protein',fontsize=20)
plt.xticks([])
plt.yticks([])
plt.tight_layout()
plt.savefig("top10_drug_heatmap.svg")
plt.show()
