# %%
import pandas as pd

# %%
df = pd.read_csv('/work/users/k/r/kritis/single_cell/PRJNA679579/gene_set_files/download_geneset.jsp?geneSetName=HES2_TARGET_GENES&fileType=TSV',sep='\t')

# %%
df
# Out:
#                        STANDARD_NAME  \
# 0                    SYSTEMATIC_NAME
# 1                         COLLECTION
# 2                         MSIGDB_URL
# 3                          NAMESPACE
# 4                  DESCRIPTION_BRIEF
# 5                   DESCRIPTION_FULL
# 6                               PMID
# 7                              GEOID
# 8                            AUTHORS
# 9                        CONTRIBUTOR
# 10                   CONTRIBUTOR_ORG
# 11                      EXACT_SOURCE
# 12            FILTERED_BY_SIMILARITY
# 13  EXTERNAL_NAMES_FOR_SIMILAR_TERMS
# 14              EXTERNAL_DETAILS_URL
# 15                    SOURCE_MEMBERS
# 16                      GENE_SYMBOLS
# 17                     FOUNDER_NAMES
#
#                                     HES2_TARGET_GENES
# 0                                              M29994
# 1                                         C3:TFT:GTRD
# 2   https://www.gsea-msigdb.org/gsea/msigdb/human/...
# ...

# %%
string = df['HES2_TARGET_GENES'][16]

# %%
my_list = [item.strip() for item in string.split(",") if item.strip()]

# %%
pd.DataFrame(my_list).to_csv('genelist.csv',index=False)

# %%
my_list
# Out:
# ['GCLC',
#  'PDK4',
#  'ZNF263',
#  'AGK',
#  'ALDH3B1',
#  'ADIPOR2',
#  'CDKL3',
#  'GAS7',
#  'E2F2',
#  'RHOBTB2',
#  'SEC62',
#  'NISCH',
#  'ZNF200',
#  'SCMH1',
#  'HIVEP2',
#  'MRC2',
#  'NME1-NME2',
#  'APBA3',
#  'SYT7',
#  'WIZ',
#  'GPRC5A',
#  'MDH1',
#  'YAF2',
#  'ATP2C1',
#  'WWTR1',
#  'AGPS',
#  'CYP24A1',
#  'CYP3A43',
#  'FHL1',
#  'SLC45A4',
#  'ALAS1',
#  'PHF20',
#  'NR1H3',
#  'VIM',
#  'PRKCH',
#  'IFNGR1',
#  'TBPL1',
#  'ABCF2',
#  'MAP2K3',
#  'CUL3',
#  'BOD1L1',
#  'ADAM28',
#  'CP',
#  'ROS1',
#  'LTBP1',
#  'NEDD4L',
#  'MCF2L2',
#  'TRAPPC3',
#  'OPN3',
#  'ZFR',
#  'DCBLD2',
#  'F7',
#  'PRDM6',
#  'MRPS35',
#  'CS',
#  'VMP1',
#  'LIMCH1',
#  'CHI3L2',
#  'SBNO2',
#  'FAM107B',
#  'KDM4A',
#  'MSANTD3',
#  'SP100',
#  'TNFRSF1A',
#  'PLEKHH3',
#  'TFE3',
#  'TTC7A',
#  'SRBD1',
#  'RASGRP2',
#  'NEDD4',
#  'SLC44A1',
#  'TMEM260',
#  'MNT',
#  'TCF3',
#  'CPSF1',
#  'RDH11',
#  'ACTN1',
#  'TFRC',
#  'P4HA2',
#  'ALPK1',
#  'CLCN4',
#  'FERMT2',
# ...
