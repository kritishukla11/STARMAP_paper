# %%
import pandas as pd

# %%
df = pd.read_csv('/work/users/k/r/kritis/single_cell/PRJNA679579/gene_set_files/download_geneset.jsp?geneSetName=NKX2_5_TARGET_GENES&fileType=TSV',sep='\t')

# %%
df
# Out:
#                        STANDARD_NAME  \
# 0                    SYSTEMATIC_NAME
# 1                         COLLECTION
# 2                         MSIGDB_URL
# 3                          NAMESPACE
# 4                  DESCRIPTION_BRIEF
# 5                   DESCRIPTION_FULL
# 6                               PMID
# 7                              GEOID
# 8                            AUTHORS
# 9                        CONTRIBUTOR
# 10                   CONTRIBUTOR_ORG
# 11                      EXACT_SOURCE
# 12            FILTERED_BY_SIMILARITY
# 13  EXTERNAL_NAMES_FOR_SIMILAR_TERMS
# 14              EXTERNAL_DETAILS_URL
# 15                    SOURCE_MEMBERS
# 16                      GENE_SYMBOLS
# 17                     FOUNDER_NAMES
#
#                                   NKX2_5_TARGET_GENES
# 0                                              M40747
# 1                                         C3:TFT:GTRD
# 2   https://www.gsea-msigdb.org/gsea/msigdb/human/...
# ...

# %%
string = df['NKX2_5_TARGET_GENES'][16]

# %%
my_list = [item.strip() for item in string.split(",") if item.strip()]

# %%
pd.DataFrame(my_list).to_csv('genelist.csv',index=False)

# %%
my_list
# Out:
# ['ANKIB1',
#  'KRIT1',
#  'M6PR',
#  'CFLAR',
#  'POLDIP2',
#  'ST7',
#  'REXO5',
#  'SPPL2B',
#  'FBXL3',
#  'OSBPL7',
#  'TMEM132A',
#  'DLX6',
#  'RALA',
#  'KDM7A',
#  'IFRD1',
#  'ST7L',
#  'MPND',
#  'NFIX',
#  'ZNF207',
#  'NCAPD2',
#  'LYPLA2',
#  'MRC2',
#  'APBA3',
#  'LARS2',
#  'PLAUR',
#  'RABGAP1',
#  'POLR3B',
#  'RNF14',
#  'CAPN1',
#  'ACP3',
#  'MDH1',
#  'CCDC88C',
#  'MATR3',
#  'GLT8D1',
#  'RUFY3',
#  'WWTR1',
#  'NRXN3',
#  'AQR',
#  'ZNF839',
#  'GRAMD1B',
#  'BIRC3',
#  'STRAP',
#  'VIM',
#  'VRK2',
#  'TBPL1',
#  'RABEP1',
#  'RANBP3',
#  'ALG1',
#  'SH3YL1',
#  'DEPDC1B',
#  'TBC1D23',
#  'VCAN',
#  'RAI14',
#  'PNKP',
#  'PHF23',
#  'PARP3',
#  'TNC',
#  'RETSAT',
#  'ADRB1',
#  'EPHA3',
#  'GEMIN8',
#  'TPR',
#  'LTBP1',
#  'LIMA1',
#  'LETMD1',
#  'BCAR1',
#  'ANAPC4',
#  'TRAPPC3',
#  'ARID4B',
#  'SDCCAG8',
#  'ITIH4',
#  'PHF21B',
#  'PKP2',
#  'ATG5',
#  'RIOK2',
#  'DNAJC25',
#  'HDAC7',
#  'GPBP1',
#  'POLD1',
#  'U2AF2',
#  'INTS13',
#  'TM7SF3',
# ...
