# %%
import pandas as pd

# %%
df = pd.read_csv('MORF_MDM2.v2024.1.Hs.tsv',sep='\t')

# %%
df
# Out:
#                        STANDARD_NAME  \
# 0                    SYSTEMATIC_NAME
# 1                         COLLECTION
# 2                         MSIGDB_URL
# 3                          NAMESPACE
# 4                  DESCRIPTION_BRIEF
# 5                   DESCRIPTION_FULL
# 6                               PMID
# 7                              GEOID
# 8                            AUTHORS
# 9                        CONTRIBUTOR
# 10                   CONTRIBUTOR_ORG
# 11                      EXACT_SOURCE
# 12            FILTERED_BY_SIMILARITY
# 13  EXTERNAL_NAMES_FOR_SIMILAR_TERMS
# 14              EXTERNAL_DETAILS_URL
# 15                    SOURCE_MEMBERS
# 16                      GENE_SYMBOLS
# 17                     FOUNDER_NAMES
#
#                                             MORF_MDM2
# 0                                               M5734
# 1                                              C4:CGN
# 2   https://www.gsea-msigdb.org/gsea/msigdb/human/...
# ...

# %%
string = df['MORF_MDM2'][16]

# %%
my_list = [item.strip() for item in string.split(",") if item.strip()]

# %%
pd.DataFrame(my_list).to_csv('genelist_2.csv',index=False)
