# %%
import pandas as pd
from scipy.io import mmread
import scipy.sparse
import scanpy as sc
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ranksums
from scipy import stats

# %%
scroot = '/work/users/k/r/kritis/single_cell/PRJNA679579'

# %%
X = mmread(f"{scroot}/GSE161824_A549_TP53.processed.matrix.mtx").tocsr()

# %%
# Load gene names and barcodes
genes = pd.read_csv(f"{scroot}/GSE161824_A549_TP53.processed.genes.csv", header=None)
barcodes = pd.read_csv(f"{scroot}/GSE161824_A549_TP53.processed.cells.csv", header=None)

# %%
import anndata as ad
adata = ad.AnnData(X)
adata.var_names = genes[0].values  # column 1 = gene symbols
adata.obs_names = barcodes[0].values

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 85778 × 1224

# %%
# Calculate basic QC metrics
sc.pp.calculate_qc_metrics(adata, inplace=True)

# Filter cells: min genes, max counts, max % mitochondrial
adata = adata[adata.obs['n_genes_by_counts'] > 200, :]
adata = adata[adata.obs['total_counts'] < 25000, :]
# Out:
# /nas/longleaf/home/kritis/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /nas/longleaf/home/kritis/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
print(adata)
# Out:
# View of AnnData object with n_obs × n_vars = 85778 × 1224
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
sc.pp.filter_genes(adata, min_cells=10)
# Out:
# /nas/longleaf/home/kritis/.local/lib/python3.10/site-packages/scanpy/preprocessing/_simple.py:283: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var["n_cells"] = number

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 85778 × 1224
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'

# %%
barcodes_mut = pd.read_csv('/work/users/k/r/kritis/database_analysis/TP53_example/MDM2_barcodes.csv')

# %%
barcode_list = barcodes_mut['cell_barcode'].tolist()

# %%
adata.obs['mut'] = adata.obs_names.isin(barcode_list)
# Optional: make it clearer
adata.obs['mut'] = adata.obs['mut'].map({True: 'Target', False: 'Other'})

# %%
adata_target = adata[adata.obs['mut'] == 'Target'].copy()
adata_other = adata[adata.obs['mut'] == 'Other'].copy()

# %%
genes = pd.read_csv('/work/users/k/r/kritis/single_cell/PRJNA679579/TP53_NFE2L1_example/genelist.csv')

# %%
gene_list = genes['0'].tolist()

# %%
gene_list = [g for g in gene_list if g in adata.var_names]
print(f"Using {len(gene_list)} genes from your list.")
# Out:
# Using 150 genes from your list.

# %%
sc.pl.violin(adata, keys=gene_list, groupby='mut', stripplot=False, jitter=False, rotation=90)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sc.pl.violin(adata, keys=gene_list, groupby='mut', stripplot=False, jitter=False, rotation=90)
#
# File ~/.local/lib/python3.10/site-packages/legacy_api_wrap/__init__.py:80, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      77 @wraps(fn)
#      78 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      79     if len(args_all) <= n_positional:
# ---> 80         return fn(*args_all, **kw)
#      82     args_pos: P.args
#      83     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File ~/.local/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:891, in violin(adata, keys, groupby, log, use_raw, stripplot, jitter, size, layer, scale, order, multi_panel, xlabel, ylabel, rotation, show, save, ax, **kwds)
#     888 kwds.setdefault("inner")
#     890 if ax is None:
# --> 891     axs, _, _, _ = setup_axes(
#     892         ax,
#     893         panels=["x"] if groupby is None else keys,
#     894         show_ticks=True,
#     895         right_margin=0.3,
#     896     )
#     897 else:
#     898     axs = [ax]
#
# File ~/.local/lib/python3.10/site-packages/scanpy/plotting/_utils.py:720, in setup_axes(ax, panels, colorbars, right_margin, left_margin, projection, show_ticks)
#     718 height = panel_pos[1][0] - bottom
#     719 if projection == "2d":
# --> 720     ax = plt.axes([left, bottom, width, height])
#     721 elif projection == "3d":
#     722     ax = plt.axes([left, bottom, width, height], projection="3d")
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:1329, in axes(arg, **kwargs)
#    1327         return fig.add_axes(pos, **kwargs)
#    1328 else:
# -> 1329     return fig.add_axes(arg, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/figure.py:576, in FigureBase.add_axes(self, *args, **kwargs)
#     573     projection_class, pkw = self._process_projection_requirements(**kwargs)
#     575     # create the new Axes using the Axes class given
# --> 576     a = projection_class(self, rect, **pkw)
#     577     key = (projection_class, pkw)
#     579 if extra_args:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:680, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     677 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     679 self._rasterization_zorder = None
# --> 680 self.clear()
#     682 # funcs used to format x and y - fall back on major formatters
#     683 self.fmt_xdata = None
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:1390, in _AxesBase.clear(self)
#    1388     self.cla()
#    1389 else:
# -> 1390     self.__clear()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:1306, in _AxesBase.__clear(self)
#    1303 self.legend_ = None
#    1304 self.containers = []
# -> 1306 self.grid(False)  # Disable grid on init to use rcParameter
#    1307 self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1308           axis=mpl.rcParams['axes.grid.axis'])
#    1309 props = font_manager.FontProperties(
#    1310     size=mpl.rcParams['axes.titlesize'],
#    1311     weight=mpl.rcParams['axes.titleweight'])
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:3240, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3238 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3239 if axis in ['x', 'both']:
# -> 3240     self.xaxis.grid(visible, which=which, **kwargs)
#    3241 if axis in ['y', 'both']:
#    3242     self.yaxis.grid(visible, which=which, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:1732, in Axis.grid(self, visible, which, **kwargs)
#    1729 if which in ['major', 'both']:
#    1730     gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1731                         if visible is None else visible)
# -> 1732     self.set_tick_params(which='major', **gridkw)
#    1733 self.stale = True
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:998, in Axis.set_tick_params(self, which, reset, **kwargs)
#     996 if which in ['major', 'both']:
#     997     self._major_tick_kw.update(kwtrans)
# --> 998     for tick in self.majorTicks:
#     999         tick._apply_params(**kwtrans)
#    1000 if which in ['minor', 'both']:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:572, in _LazyTickList.__get__(self, instance, owner)
#     570     instance.majorTicks = []
#     571     tick = instance._get_tick(major=True)
# --> 572     instance.majorTicks.append(tick)
#     573     return instance.majorTicks
#     574 else:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:571, in _LazyTickList.__get__(self, instance, owner)
#     569 if self._major:
#     570     instance.majorTicks = []
# --> 571     tick = instance._get_tick(major=True)
#     572     instance.majorTicks.append(tick)
#     573     return instance.majorTicks
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:1597, in Axis._get_tick(self, major)
#    1593     raise NotImplementedError(
#    1594         f"The Axis subclass {self.__class__.__name__} must define "
#    1595         "_tick_class or reimplement _get_tick()")
#    1596 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1597 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:398, in XTick.__init__(self, *args, **kwargs)
#     397 def __init__(self, *args, **kwargs):
# --> 398     super().__init__(*args, **kwargs)
#     399     # x in data coords, y in axes coords
#     400     ax = self.axes
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:170, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, labelfontfamily, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kwargs)
#     160 self.tick1line = mlines.Line2D(
#     161     [], [],
#     162     color=color, linestyle="none", zorder=zorder, visible=tick1On,
#     163     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     164 )
#     165 self.tick2line = mlines.Line2D(
#     166     [], [],
#     167     color=color, linestyle="none", zorder=zorder, visible=tick2On,
#     168     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     169 )
# --> 170 self.gridline = mlines.Line2D(
#     171     [], [],
#     172     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     173     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     174     **grid_kw,
#     175 )
#     176 self.gridline.get_path()._interpolation_steps = \
#     177     GRIDLINE_INTERPOLATION_STEPS
#     178 self.label1 = mtext.Text(
#     179     np.nan, np.nan,
#     180     fontsize=labelsize, color=labelcolor, visible=label1On,
#     181     fontfamily=labelfontfamily, rotation=self._labelrotation[1])
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/lines.py:401, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     398 self._markerfacecoloralt = None
#     400 self.set_markerfacecolor(markerfacecolor)  # Normalizes None to rc.
# --> 401 self.set_markerfacecoloralt(markerfacecoloralt)
#     402 self.set_markeredgecolor(markeredgecolor)  # Normalizes None to rc.
#     403 self.set_markeredgewidth(markeredgewidth)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/lines.py:1244, in Line2D.set_markerfacecoloralt(self, fc)
#    1236 def set_markerfacecoloralt(self, fc):
#    1237     """
#    1238     Set the alternate marker face color.
#    1239
#    (...)
#    1242     fc : :mpltype:`color`
#    1243     """
# -> 1244     self._set_markercolor("markerfacecoloralt", False, fc)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/lines.py:1214, in Line2D._set_markercolor(self, name, has_rcdefault, val)
#    1212     if neq.any() if isinstance(neq, np.ndarray) else neq:
#    1213         self.stale = True
# -> 1214 setattr(self, attr, val)
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x7f07be33e4d0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:265, in _draw_all_if_interactive()
#     263 def _draw_all_if_interactive() -> None:
#     264     if matplotlib.is_interactive():
# --> 265         draw_all()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py:1919, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1917 if not self._is_idle_drawing:
#    1918     with self._idle_draw_cntx():
# -> 1919         self.draw(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     380 def draw(self):
#     381     # docstring inherited
# --> 382     self.renderer = self.get_renderer()
#     383     self.renderer.clear()
#     384     # Acquire a lock on the shared font cache.
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:397, in FigureCanvasAgg.get_renderer(self)
#     395 reuse_renderer = (self._lastKey == key)
#     396 if not reuse_renderer:
# --> 397     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     398     self._lastKey = key
#     399 return self.renderer
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:70, in RendererAgg.__init__(self, width, height, dpi)
#      68 self.width = width
#      69 self.height = height
# ---> 70 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      71 self._filter_renderers = []
#      73 self._update_methods()
#
# ValueError: Image size of 120690x480 pixels is too large. It must be less than 2^16 in each direction.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File /nas/longleaf/rhel8/apps/anaconda/2023.03.ood/lib/python3.10/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py:2181, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2176 layout_engine = self.figure.get_layout_engine()
#    2177 if layout_engine is not None or bbox_inches == "tight":
#    2178     # we need to trigger a draw before printing to make sure
#    2179     # CL works.  "tight" also needs a draw to get the right
#    2180     # locations:
# -> 2181     renderer = _get_renderer(
#    2182         self.figure,
#    2183         functools.partial(
#    2184             print_method, orientation=orientation)
#    2185     )
#    2186     # we do this instead of `self.figure.draw_without_rendering`
#    2187     # so that we can inject the orientation
#    2188     with getattr(renderer, "_draw_disabled", nullcontext)():
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py:1602, in _get_renderer(figure, print_method)
#    1599     print_method = stack.enter_context(
#    1600         figure.canvas._switch_canvas_and_return_print_method(fmt))
#    1601 try:
# -> 1602     print_method(io.BytesIO())
#    1603 except Done as exc:
#    1604     renderer, = exc.args
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py:2068, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2064     optional_kws = {  # Passed by print_figure for other renderers.
#    2065         "dpi", "facecolor", "edgecolor", "orientation",
#    2066         "bbox_inches_restore"}
#    2067     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2068     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2069         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2070 else:  # Let third-parties do as they see fit.
#    2071     print_method = meth
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:444, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     439 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     440     """
#     441     Draw the canvas, then save it using `.image.imsave` (to which
#     442     *pil_kwargs* and *metadata* are forwarded).
#     443     """
# --> 444     FigureCanvasAgg.draw(self)
#     445     mpl.image.imsave(
#     446         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     380 def draw(self):
#     381     # docstring inherited
# --> 382     self.renderer = self.get_renderer()
#     383     self.renderer.clear()
#     384     # Acquire a lock on the shared font cache.
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:397, in FigureCanvasAgg.get_renderer(self)
#     395 reuse_renderer = (self._lastKey == key)
#     396 if not reuse_renderer:
# --> 397     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     398     self._lastKey = key
#     399 return self.renderer
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:70, in RendererAgg.__init__(self, width, height, dpi)
#      68 self.width = width
#      69 self.height = height
# ---> 70 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      71 self._filter_renderers = []
#      73 self._update_methods()
#
# ValueError: Image size of 120690x480 pixels is too large. It must be less than 2^16 in each direction.

# %%
X = adata[:, gene_list].X
if not isinstance(X, np.ndarray):
    X = X.toarray()  # in case it's sparse

avg_expr = X.mean(axis=1)
adata.obs['gene_signature_avg'] = avg_expr

# %%
sns.violinplot(data=adata.obs, x='mut', y='gene_signature_avg', inner='box', palette='pastel')
plt.title('Average Expression of Gene Signature per Cell')
plt.ylabel('Avg. Expression of Selected Genes')
plt.xlabel('Group')
plt.show()
# Out:
# /tmp/ipykernel_3407784/386510469.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=adata.obs, x='mut', y='gene_signature_avg', inner='box', palette='pastel')

# %%
expressing = (adata[:, gene_list].X.toarray().sum(axis=1) > 0)
adata.obs['expressing_signature'] = np.where(expressing, 'Expressing', 'Not expressing')

# Then plot just the expressing ones
sns.violinplot(data=adata.obs[expressing], x='mut', y='gene_signature_avg')
# Out:
# <Axes: xlabel='mut', ylabel='gene_signature_avg'>

# %%
target_expr = adata.obs.loc[adata.obs['mut'] == 'Target', 'gene_signature_avg']
other_expr = adata.obs.loc[adata.obs['mut'] == 'Other', 'gene_signature_avg']

print("Means:", target_expr.mean(), other_expr.mean())
print("Medians:", target_expr.median(), other_expr.median())
print("Std Devs:", target_expr.std(), other_expr.std())
# Out:
# Means: 0.00035441141495398226 -0.002780303406437076
# Medians: -0.03218389810866667 -0.03460675093
# Std Devs: 0.21529085125892536 0.2112680195812353

# %%
group_1.dropna().mean()
# Out:
# 0.00035441141495398226

# %%
group_2.dropna().mean()
# Out:
# -0.002780303406437076

# %%
group_1 = adata.obs[adata.obs['mut'] == 'Target']['gene_signature_avg']
group_2 = adata.obs[adata.obs['mut'] == 'Other']['gene_signature_avg']

stat, pval = ranksums(group_1.dropna(), group_2.dropna())
print(f'Wilcoxon p-value: {pval}')
# Out:
# Wilcoxon p-value: 0.11549097934238305

# %%
t_stat, p_value = stats.ttest_ind(group_1.dropna(), group_2.dropna())
print("T statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T statistic: 1.875179465297551
# P-value: 0.060771432767881696

# %%
sc.pl.dotplot(adata, var_names=gene_list, groupby='mut')

# %%
is_target = adata.obs['mut'] == 'Target'
is_other = adata.obs['mut'] == 'Other'

# Define full gene sets
all_genes = adata.var_names.tolist()
not_gene_list = list(set(all_genes) - set(gene_list))

def avg_expr(genes, cells):
    X = adata[cells, genes].X
    if not isinstance(X, np.ndarray):
        X = X.toarray()
    return X.mean()

data = []

for group_name, mask in [('Target', is_target), ('Other', is_other)]:
    # In gene list
    mean_in_list = avg_expr(gene_list, mask)
    # Not in gene list
    mean_not_in_list = avg_expr(not_gene_list, mask)

    data.append({'Group': group_name, 'Subset': 'In gene list', 'Mean': mean_in_list})
    data.append({'Group': group_name, 'Subset': 'Not in gene list', 'Mean': mean_not_in_list})

df = pd.DataFrame(data)

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x='Group', y='Mean', hue='Subset', s=200, style='Subset')

# Optional: improve layout
plt.title('Mean Expression: Gene List vs Background')
plt.ylabel('Average Expression')
plt.legend(title='Gene Subset')
plt.tight_layout()
plt.show()

# %%
sc.tl.rank_genes_groups(adata, groupby='mut', groups=['Target'], reference='Other', method='wilcoxon')
# Out:
# /nas/longleaf/home/kritis/.local/lib/python3.10/site-packages/scanpy/tools/_rank_genes_groups.py:461: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(

# %%
sc.get.rank_genes_groups_df(adata, group='Target')
# Out:
#           names     scores  logfoldchanges         pvals     pvals_adj
# 0     HIST2H2BE   7.368357             NaN  1.727432e-13  3.020538e-11
# 1       RASSF10   7.282773             NaN  3.270268e-13  4.523190e-11
# 2       LDLRAD4   7.280499       -1.602722  3.325875e-13  4.523190e-11
# 3      HHIP-AS1   6.848704             NaN  7.452195e-12  8.292260e-10
# 4        ITGA11   6.609318       -1.747571  3.860956e-11  3.938175e-09
# ...         ...        ...             ...           ...           ...
# 1219       FDXR  -8.615104             NaN  6.987834e-18  1.710622e-15
# 1220    ALDH3A1 -10.908886             NaN  1.045296e-27  3.198605e-25
# 1221     CDKN1A -11.332732             NaN  9.034148e-30  3.685933e-27
# 1222     PHLDA3 -11.410033             NaN  3.725854e-30  2.280222e-27
# 1223     RPS27L -17.908575             NaN  1.010918e-71  1.237364e-68
#
# [1224 rows x 5 columns]

# %%
sc.pl.heatmap(adata, var_names=gene_list, groupby='mut', use_raw=False)

# %%
import numpy as np

# Convert sparse to dense if needed
X = adata[:, gene_list].X.toarray() if not isinstance(adata.X, np.ndarray) else adata[:, gene_list].X

# Create a DataFrame of expression values
import pandas as pd
expr_df = pd.DataFrame(X, columns=gene_list, index=adata.obs_names)
expr_df['mut'] = adata.obs['mut'].values

# Group by 'Target' and 'Other' and compute mean expression
signature_stats = expr_df.groupby('mut').mean()
print(signature_stats)
# Out:
#              SCD     NCOA7   GADD45A      ILF2    MT-ND6       ANG
# mut
# Other   0.005924  0.007745  0.003335 -0.006776 -0.007727 -0.002051
# Target -0.024624 -0.001526 -0.022310  0.004696 -0.008276 -0.012313
# /tmp/ipykernel_3427414/1533957719.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   signature_stats = expr_df.groupby('mut').mean()

# %%
gene_set = [g for g in gene_list if g in adata_target.var_names]

# All other genes
other_genes = [g for g in adata_target.var_names if g not in gene_set]

# %%
gene_idx = [adata_target.var_names.get_loc(g) for g in gene_set]
other_idx = [i for i in range(adata_target.shape[1]) if i not in gene_idx]

# %%
X = adata_target.X.toarray() if not isinstance(adata_target.X, np.ndarray) else adata_target.X

# Compute per-cell mean expression
sig_expr = X[:, gene_idx].mean(axis=1)
other_expr = X[:, other_idx].mean(axis=1)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Tidy DataFrame
df_long = pd.DataFrame({
    '4-gene signature': sig_expr,
    'Other genes': other_expr
}).melt(var_name='Gene Set', value_name='Average Expression')

# Plot
sns.violinplot(x='Gene Set', y='Average Expression', data=df_long, inner='box', palette='pastel')
plt.title("Expression Comparison in Target Cells")
plt.show()
# Out:
# /tmp/ipykernel_3427414/1962594932.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Gene Set', y='Average Expression', data=df_long, inner='box', palette='pastel')

# %%
from scipy.stats import wilcoxon

stat, pval = wilcoxon(sig_expr, other_expr)
print(f"Wilcoxon signed-rank test p-value: {pval:.3e}")
# Out:
# Wilcoxon signed-rank test p-value: 9.584e-12
