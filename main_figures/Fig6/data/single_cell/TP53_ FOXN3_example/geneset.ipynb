# %%
import pandas as pd

# %%
df = pd.read_csv('/work/users/k/r/kritis/single_cell/PRJNA679579/gene_set_files/download_geneset.jsp?geneSetName=FOXN3_TARGET_GENES&fileType=TSV',sep='\t')

# %%
df
# Out:
#                        STANDARD_NAME  \
# 0                    SYSTEMATIC_NAME
# 1                         COLLECTION
# 2                         MSIGDB_URL
# 3                          NAMESPACE
# 4                  DESCRIPTION_BRIEF
# 5                   DESCRIPTION_FULL
# 6                               PMID
# 7                              GEOID
# 8                            AUTHORS
# 9                        CONTRIBUTOR
# 10                   CONTRIBUTOR_ORG
# 11                      EXACT_SOURCE
# 12            FILTERED_BY_SIMILARITY
# 13  EXTERNAL_NAMES_FOR_SIMILAR_TERMS
# 14              EXTERNAL_DETAILS_URL
# 15                    SOURCE_MEMBERS
# 16                      GENE_SYMBOLS
# 17                     FOUNDER_NAMES
#
#                                    FOXN3_TARGET_GENES
# 0                                              M29973
# 1                                         C3:TFT:GTRD
# 2   https://www.gsea-msigdb.org/gsea/msigdb/human/...
# ...

# %%
string = df['FOXN3_TARGET_GENES'][16]

# %%
my_list = [item.strip() for item in string.split(",") if item.strip()]

# %%
pd.DataFrame(my_list).to_csv('genelist.csv',index=False)
